# %% [markdown]
# # Starting workshop xD!

# %%
import dlt
import requests
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## 1. Line-by-Line mode Educational Explanation

# %%
url = "https://us-central1-dlthub-analytics.cloudfunctions.net/data_engineering_zoomcamp_api"
response = requests.get(url)
data = response.json()

# %%
 # Convert to DataFrame
df = pd.DataFrame(data)
df['Trip_Pickup_DateTime'] = pd.to_datetime(df['Trip_Pickup_DateTime'])

# %%
df
# Out:
#        End_Lat    End_Lon  Fare_Amt  Passenger_Count Payment_Type Rate_Code  \
# 0    40.742963 -73.980072      45.0                1       Credit      None
# 1    40.740187 -74.005698       6.5                1       Credit      None
# 2    40.718043 -74.004745      12.5                5       Credit      None
# 3    40.739637 -73.985233       4.9                1         CASH      None
# 4    40.730032 -73.852693      25.7                1         CASH      None
# ..         ...        ...       ...              ...          ...       ...
# 995  40.742998 -73.919065       6.9                1         CASH      None
# 996  40.731953 -73.985330       7.3                1         CASH      None
# 997  40.712640 -73.998870       5.7                1         CASH      None
# 998  40.732998 -74.007113       7.3                2         CASH      None
# 999  40.767120 -73.953602       4.5                5         CASH      None
#
#      Start_Lat  Start_Lon  Tip_Amt  Tolls_Amt  Total_Amt  Trip_Distance  \
# 0    40.641525 -73.787442      9.0       4.15      58.15          17.52
# 1    40.722065 -74.009767      1.0       0.00       8.50           1.56
# 2    40.761945 -73.983038      2.0       0.00      15.50           3.37
# 3    40.749802 -73.992247      0.0       0.00       5.40           1.11
# 4    40.776825 -73.949233      0.0       4.15      29.85          11.09
# ..         ...        ...      ...        ...        ...            ...
# 995  40.743523 -73.918735      0.0       0.00       6.90           1.83
# 996  40.733143 -74.006408      0.0       0.00       7.80           1.59
# 997  40.711865 -74.010158      0.0       0.00       5.70           0.79
# 998  40.744658 -73.992063      0.0       0.00       7.80           1.87
# 999  40.778478 -73.945387      0.0       0.00       4.50           0.91
#
#     Trip_Dropoff_DateTime Trip_Pickup_DateTime mta_tax  store_and_forward  \
# 0     2009-06-14 23:48:00  2009-06-14 23:23:00    None                NaN
# 1     2009-06-18 17:43:00  2009-06-18 17:35:00    None                NaN
# 2     2009-06-10 18:27:00  2009-06-10 18:08:00    None                NaN
# 3     2009-06-14 23:58:00  2009-06-14 23:54:00    None                NaN
# 4     2009-06-13 13:23:00  2009-06-13 13:01:00    None                NaN
# ..                    ...                  ...     ...                ...
# 995   2009-06-10 06:23:00  2009-06-10 06:16:00    None                NaN
# 996   2009-06-10 05:11:00  2009-06-10 05:02:00    None                NaN
# 997   2009-06-13 12:45:00  2009-06-13 12:37:00    None                NaN
# 998   2009-06-09 21:34:00  2009-06-09 21:25:00    None                NaN
# 999   2009-06-13 08:59:00  2009-06-13 08:56:00    None                NaN
#
#      surcharge vendor_name
# 0          0.0         VTS
# 1          1.0         VTS
# 2          1.0         VTS
# 3          0.5         VTS
# 4          0.0         VTS
# ..         ...         ...
# 995        0.0         VTS
# 996        0.5         VTS
# 997        0.0         VTS
# 998        0.5         VTS
# 999        0.0         VTS
#
# [1000 rows x 18 columns]

# %%
# Define buckets, 
# - `cut` divide continuous values into bins, in this case datetime intervals.
df['tag'] = pd.cut(
df['Trip_Pickup_DateTime'],
    bins=[
        pd.Timestamp("2009-06-01"),
        pd.Timestamp("2009-06-10"),
        pd.Timestamp("2009-06-20"),
        pd.Timestamp("2009-06-30")
    ],
    labels=["first_10_days", "second_10_days", "last_10_days"],
    right=False
)

# %%
df['tag'].value_counts(dropna=False)
# Out:
# tag
# first_10_days     481
# second_10_days    295
# last_10_days      222
# NaN                 2
# Name: count, dtype: int64

# %%
# Optional: fill NaN with 'out_of_range' for clarity
df['tag'] = df['tag'].cat.add_categories('out_of_range').fillna('out_of_range')

# %%
# count by tag
df['tag'].value_counts(dropna=False)
# Out:
# tag
# first_10_days     481
# second_10_days    295
# last_10_days      222
# out_of_range        2
# Name: count, dtype: int64

# %% [markdown]
# ## Now lets see using @A decorator to wrap a function.
#
# - giving it extra functionality without modifying its internal code.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Step 1: Create DLT resource
@dlt.resource(write_disposition="replace", name="zoomcamp_data")
def zoomcamp_data():
    url = "https://us-central1-dlthub-analytics.cloudfunctions.net/data_engineering_zoomcamp_api"
    response = requests.get(url)
    data = response.json()

    # Convert to DataFrame
    df = pd.DataFrame(data)
    df['Trip_Pickup_DateTime'] = pd.to_datetime(df['Trip_Pickup_DateTime'])

    # Define buckets
    df['tag'] = pd.cut(
        df['Trip_Pickup_DateTime'],
        bins=[
            pd.Timestamp("2009-06-01"),
            pd.Timestamp("2009-06-10"),
            pd.Timestamp("2009-06-20"),
            pd.Timestamp("2009-06-30")
        ],
        labels=["first_10_days", "second_10_days", "last_10_days"],
        right=False
    )

    # Drop rows not in the specified range
    # df = df[df['tag'].notnull()] #Lets see what happend with fill Nan to `out_of_range`
    yield df

# %%
# Step 2: Create Pipeline
pipeline = dlt.pipeline(
    pipeline_name="zoomcamp_pipeline",
    destination="duckdb",
    dataset_name="zoomcamp_tagged_data"
)

# %%
# Step 3: run the pipeline

load_info = pipeline.run(zoomcamp_data())
# Out:
# 2025-07-06 19:04:42,621|[WARNING]|157731|130289585231360|dlt|validate.py|verify_normalized_table:57|In schema `zoomcamp`: The following columns in table 'zoomcamp_data' did not receive any data during this load and therefore could not have their types inferred:
#   - rate_code
#   - mta_tax
#
# Unless type hints are provided, these columns will not be materialized in the destination.
# One way to provide type hints is to use the 'columns' argument in the '@dlt.resource' decorator.  For example:
#
# @dlt.resource(columns={'rate_code': {'data_type': 'text'}})

# %%
print(pipeline.last_trace)
# Out:
# Run started at 2025-07-07 01:04:40.318881+00:00 and COMPLETED in 2.58 seconds with 4 steps.
# Step extract COMPLETED in 2.09 seconds.
#
# Load package 1751850280.5308163 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 0.03 seconds.
# Normalized data for the following tables:
# - zoomcamp_data: 1000 row(s)
#
# Load package 1751850280.5308163 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step load COMPLETED in 0.27 seconds.
# Pipeline zoomcamp_pipeline load step completed in 0.12 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset zoomcamp_tagged_data
# The duckdb destination used duckdb:////home/radianv/projects/data_talk_club/local-llm-zoomcamp/workshops/dlt/code/zoomcamp_pipeline.duckdb location to store data
# Load package 1751850280.5308163 is LOADED and contains no failed jobs
#
# Step run COMPLETED in 2.58 seconds.
# Pipeline zoomcamp_pipeline load step completed in 0.12 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset zoomcamp_tagged_data
# The duckdb destination used duckdb:////home/radianv/projects/data_talk_club/local-llm-zoomcamp/workshops/dlt/code/zoomcamp_pipeline.duckdb location to store data
# Load package 1751850280.5308163 is LOADED and contains no failed jobs

# %%
#Lets trying to retrieve the data that was previously loaded into destination (in this case, DuckDB) using the DLT pipeline interface.

dataset = pipeline.dataset().zoomcamp_data.df()

# %%
dataset
# Out:
#        end_lat    end_lon  fare_amt  passenger_count payment_type  start_lat  \
# 0    40.742963 -73.980072      45.0                1       Credit  40.641525
# 1    40.740187 -74.005698       6.5                1       Credit  40.722065
# 2    40.718043 -74.004745      12.5                5       Credit  40.761945
# 3    40.739637 -73.985233       4.9                1         CASH  40.749802
# 4    40.730032 -73.852693      25.7                1         CASH  40.776825
# ..         ...        ...       ...              ...          ...        ...
# 995  40.742998 -73.919065       6.9                1         CASH  40.743523
# 996  40.731953 -73.985330       7.3                1         CASH  40.733143
# 997  40.712640 -73.998870       5.7                1         CASH  40.711865
# 998  40.732998 -74.007113       7.3                2         CASH  40.744658
# 999  40.767120 -73.953602       4.5                5         CASH  40.778478
#
#      start_lon  tip_amt  tolls_amt  total_amt  trip_distance  \
# 0   -73.787442      9.0       4.15      58.15          17.52
# 1   -74.009767      1.0       0.00       8.50           1.56
# 2   -73.983038      2.0       0.00      15.50           3.37
# 3   -73.992247      0.0       0.00       5.40           1.11
# 4   -73.949233      0.0       4.15      29.85          11.09
# ..         ...      ...        ...        ...            ...
# 995 -73.918735      0.0       0.00       6.90           1.83
# 996 -74.006408      0.0       0.00       7.80           1.59
# 997 -74.010158      0.0       0.00       5.70           0.79
# 998 -73.992063      0.0       0.00       7.80           1.87
# 999 -73.945387      0.0       0.00       4.50           0.91
#
#     trip_dropoff_date_time trip_pickup_date_time  store_and_forward  \
# 0      2009-06-14 23:48:00   2009-06-14 23:23:00                NaN
# 1      2009-06-18 17:43:00   2009-06-18 17:35:00                NaN
# 2      2009-06-10 18:27:00   2009-06-10 18:08:00                NaN
# 3      2009-06-14 23:58:00   2009-06-14 23:54:00                NaN
# 4      2009-06-13 13:23:00   2009-06-13 13:01:00                NaN
# ..                     ...                   ...                ...
# 995    2009-06-10 06:23:00   2009-06-10 06:16:00                NaN
# 996    2009-06-10 05:11:00   2009-06-10 05:02:00                NaN
# 997    2009-06-13 12:45:00   2009-06-13 12:37:00                NaN
# 998    2009-06-09 21:34:00   2009-06-09 21:25:00                NaN
# 999    2009-06-13 08:59:00   2009-06-13 08:56:00                NaN
#
#      surcharge vendor_name             tag
# 0          0.0         VTS  second_10_days
# 1          1.0         VTS  second_10_days
# 2          1.0         VTS  second_10_days
# 3          0.5         VTS  second_10_days
# 4          0.0         VTS  second_10_days
# ..         ...         ...             ...
# 995        0.0         VTS  second_10_days
# 996        0.5         VTS  second_10_days
# 997        0.0         VTS  second_10_days
# 998        0.5         VTS   first_10_days
# 999        0.0         VTS  second_10_days
#
# [1000 rows x 17 columns]

# %%
dataset["tag"].value_counts()
# Out:
# tag
# first_10_days     481
# second_10_days    295
# last_10_days      222
# Name: count, dtype: int64

# %% [markdown]
# # Lets load data into Cognee!

# %%
import cognee
from cognee.shared.logging_utils import get_logger, ERROR
from cognee.api.v1.visualize.visualize import visualize_graph
from cognee.api.v1.search import SearchType
from cognee.modules.engine.models import NodeSet
import os

#from dotenv import load_dotenv
#load_dotenv()
# Out:
# 2025-07-07T01:04:56.976793 [info     ] Logging initialized            [cognee.shared.logging_utils] cognee_version=0.2.0 os_info='Linux 6.11.0-29-generic (#29~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Thu Jun 26 14:16:59 UTC 2)' python_version=3.10.13 structlog_version=25.4.0
#
# 2025-07-07T01:04:56.977577 [info     ] Want to learn more? Visit the Cognee documentation: https://docs.cognee.ai [cognee.shared.logging_utils]
#
# HTTP Request: GET https://raw.githubusercontent.com/BerriAI/litellm/main/model_prices_and_context_window.json "HTTP/1.1 200 OK"

# %%
#os.environ["LLM_API_KEY"] = os.environ.get('OPENAI_API_KEY') # it can be OpenAI API key

# %%
async def main():
    await cognee.prune.prune_data()
    await cognee.prune.prune_system(metadata=True)

    # Add the first 10 days
    df_set1 = dataset.loc[dataset["tag"] == "first_10_days"]
    df_set1.drop(columns=["tag"], inplace=True)
    df_set1 = df_set1.to_json(orient="records", lines=False)
    await cognee.add(df_set1, node_set=["first_10_days"])

    # Add the second 10 days
    df_set2 = dataset.loc[dataset["tag"] == "second_10_days"]
    df_set2.drop(columns=["tag"], inplace=True)
    df_set2 = df_set2.to_json(orient="records", lines=False)
    await cognee.add(df_set2, node_set=["second_10_days"])

    # Add the last 10 days
    df_set3 = dataset.loc[dataset["tag"] == "last_10_days"]
    df_set3.drop(columns=["tag"], inplace=True)
    df_set3 = df_set3.to_json(orient="records", lines=False)
    await cognee.add(df_set3, node_set=["last_10_days"])

    await cognee.cognify()

    #visualization_path = "/content/.artifacts/graph_visualization.html"
    visualization_path = "graph_output/graph_visualization.html"
    await visualize_graph(visualization_path)

# %%
await main()
# Out:
# 2025-07-07T01:15:10.181046 [info     ] Cleared all data from graph while preserving structure [cognee.shared.logging_utils]
# 2025-07-07T01:15:10.210703 [info     ] Deleted Kuzu database files at /home/radianv/anaconda3/envs/llm-zoomcamp/lib/python3.10/site-packages/cognee/.cognee_system/databases/cognee_graph_kuzu [cognee.shared.logging_utils]
# 2025-07-07T01:15:10.253147 [info     ] Database deleted successfully. [cognee.shared.logging_utils]/tmp/ipykernel_157731/463349275.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_set1.drop(columns=["tag"], inplace=True)
#
# 2025-07-07T01:15:10.616530 [info     ] Pipeline run started: `8492166f-f591-5087-8636-82ce555d52ba` [run_tasks(tasks: [Task], data)]
# User 9c5d371c-f82f-4c28-987d-bd637e8d3f4c has registered.
# 2025-07-07T01:15:13.041544 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T01:15:13.554362 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
# 2025-07-07T01:15:14.309668 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
# 2025-07-07T01:15:14.700868 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T01:15:15.078633 [info     ] Pipeline run completed: `8492166f-f591-5087-8636-82ce555d52ba` [run_tasks(tasks: [Task], data)]/tmp/ipykernel_157731/463349275.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_set2.drop(columns=["tag"], inplace=True)
#
# 2025-07-07T01:15:15.565543 [info     ] Pipeline run started: `8492166f-f591-5087-8636-82ce555d52ba` [run_tasks(tasks: [Task], data)]
# 2025-07-07T01:15:16.000858 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T01:15:16.421306 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
# 2025-07-07T01:15:17.097331 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
# 2025-07-07T01:15:17.466750 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T01:15:17.957254 [info     ] Pipeline run completed: `8492166f-f591-5087-8636-82ce555d52ba` [run_tasks(tasks: [Task], data)]/tmp/ipykernel_157731/463349275.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_set3.drop(columns=["tag"], inplace=True)
#
# 2025-07-07T01:15:18.426814 [info     ] Pipeline run started: `8492166f-f591-5087-8636-82ce555d52ba` [run_tasks(tasks: [Task], data)]
# 2025-07-07T01:15:18.879272 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T01:15:19.290197 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
# 2025-07-07T01:15:19.955639 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
# 2025-07-07T01:15:20.319801 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
# 2025-07-07T01:15:20.721843 [info     ] Pipeline run completed: `8492166f-f591-5087-8636-82ce555d52ba` [run_tasks(tasks: [Task], data)]
# 2025-07-07T01:15:21.142936 [info     ] Ontology file 'None' not found. No owl ontology will be attached to the graph. [OntologyAdapter]
# 2025-07-07T01:15:21.179509 [info     ] Pipeline run started: `323d968a-862f-52a4-92d5-6b83cba96071` [run_tasks(tasks: [Task], data)]
# 2025-07-07T01:15:21.645656 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
# 2025-07-07T01:15:22.054844 [info     ] Coroutine task started: `check_permissions_on_dataset` [run_tasks_base]
# 2025-07-07T01:15:22.473697 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
# 2025-07-07T01:15:23.153287 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:23 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:15:27 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:27 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:28 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:28 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:30 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:49 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:49 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:55 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:15:55 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:16:09 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:16:09 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:16:48 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:16:48 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:38 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:38 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# 2025-07-07T01:18:38.482566 [info     ] No close match found for 'vendor' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:18:38.483648 [info     ] No close match found for 'vts' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.484598 [info     ] No close match found for 'payment type' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:18:38.486566 [info     ] No close match found for 'credit' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.487683 [info     ] No close match found for 'cash' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.489120 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:18:38.490207 [info     ] No close match found for '2009-06-14' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.491410 [info     ] No close match found for '2009-06-18' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.492608 [info     ] No close match found for '2009-06-10' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.494520 [info     ] No close match found for 'trip' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:18:38.496397 [info     ] No close match found for 'trip 1' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.498609 [info     ] No close match found for 'trip 2' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.500269 [info     ] No close match found for 'trip 3' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.501442 [info     ] No close match found for 'trip 4' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.503105 [info     ] No close match found for 'trip 5' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.504294 [info     ] No close match found for 'trip 6' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.505327 [info     ] No close match found for 'trip 7' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.506931 [info     ] No close match found for 'trip 8' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.508931 [info     ] No close match found for 'trip 9' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.510889 [info     ] No close match found for 'trip 10' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.512710 [info     ] No close match found for 'trip 11' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.514068 [info     ] No close match found for 'trip 12' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.514993 [info     ] No close match found for 'trip 13' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.516049 [info     ] No close match found for 'trip 14' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.517790 [info     ] No close match found for 'trip 15' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.519620 [info     ] No close match found for 'trip 16' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.520766 [info     ] No close match found for 'trip 17' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.521673 [info     ] No close match found for 'trip 18' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.523584 [info     ] No close match found for 'trip 19' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.524661 [info     ] No close match found for 'trip 20' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.526523 [info     ] No close match found for 'trip 21' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.527819 [info     ] No close match found for 'trip 22' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.529492 [info     ] No close match found for 'trip 23' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.530439 [info     ] No close match found for 'trip 24' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.531289 [info     ] No close match found for 'trip 25' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.532315 [info     ] No close match found for 'trip 26' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.535058 [info     ] No close match found for 'trip 27' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.536083 [info     ] No close match found for 'trip 28' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.537325 [info     ] No close match found for 'trip 29' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.538698 [info     ] No close match found for 'trip 30' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.540166 [info     ] No close match found for 'trip 31' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.541691 [info     ] No close match found for 'trip 32' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.543166 [info     ] No close match found for 'trip 33' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.546503 [info     ] No close match found for 'trip 34' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.548559 [info     ] No close match found for 'trip 35' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.550449 [info     ] No close match found for 'trip 36' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.552037 [info     ] No close match found for 'trip 37' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.554016 [info     ] No close match found for 'trip 38' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.555920 [info     ] No close match found for 'trip 39' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.556792 [info     ] No close match found for 'trip 40' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.557681 [info     ] No close match found for 'trip 41' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.559369 [info     ] No close match found for 'trip 42' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.561684 [info     ] No close match found for 'trip 43' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.563124 [info     ] No close match found for 'trip 44' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.564069 [info     ] No close match found for 'trip 45' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.564943 [info     ] No close match found for 'trip 46' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.566123 [info     ] No close match found for 'trip 47' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.567140 [info     ] No close match found for 'trip 48' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.568063 [info     ] No close match found for 'trip 49' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.568966 [info     ] No close match found for 'trip 50' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.570072 [info     ] No close match found for 'trip 51' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.571366 [info     ] No close match found for 'trip 52' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.572749 [info     ] No close match found for 'trip 53' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.574129 [info     ] No close match found for 'trip 54' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.577228 [info     ] No close match found for 'trip 55' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.578805 [info     ] No close match found for 'trip 56' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.580177 [info     ] No close match found for 'trip 57' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.581300 [info     ] No close match found for 'trip 58' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.583587 [info     ] No close match found for 'trip 59' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.584971 [info     ] No close match found for 'trip 60' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.587569 [info     ] No close match found for 'trip 61' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.588714 [info     ] No close match found for 'trip 62' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.589698 [info     ] No close match found for 'trip 63' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.594948 [info     ] No close match found for '2009-06-19' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.597383 [info     ] No close match found for '2009-06-12' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.598310 [info     ] No close match found for '2009-06-13' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.599958 [info     ] No close match found for '2009-06-17' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.603146 [info     ] No close match found for '2009-06-21' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.605050 [info     ] No close match found for '2009-06-20' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.606639 [info     ] No close match found for '2009-06-27' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.608843 [info     ] No close match found for '2009-06-28' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.612374 [info     ] No close match found for '2009-06-29' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.615260 [info     ] No close match found for '2009-06-24' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.617424 [info     ] No close match found for '2009-06-25' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.618962 [info     ] No close match found for 'cmt' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.620290 [info     ] No close match found for '2009-06-23' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.622087 [info     ] No close match found for '2009-06-26' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.623897 [info     ] No close match found for '2009-06-20' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.625316 [info     ] No close match found for '2009-06-21' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.627152 [info     ] No close match found for '2009-06-22' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.630584 [info     ] No close match found for '2009-06-21t16:40:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.633091 [info     ] No close match found for '2009-06-21t20:48:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.634428 [info     ] No close match found for '2009-06-21t21:08:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.636608 [info     ] No close match found for '2009-06-24t15:16:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.638034 [info     ] No close match found for '2009-06-21t19:09:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.639135 [info     ] No close match found for '2009-06-21t18:47:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.640427 [info     ] No close match found for '2009-06-21t17:01:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.641957 [info     ] No close match found for '2009-06-21t19:51:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.644186 [info     ] No close match found for '2009-06-21t18:03:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.645751 [info     ] No close match found for '2009-06-23t16:21:58' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.646815 [info     ] No close match found for '2009-06-27t18:53:37' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.647905 [info     ] No close match found for '2009-06-23t08:49:34' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.648971 [info     ] No close match found for '2009-06-20t11:45:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.650048 [info     ] No close match found for '2009-06-20t13:59:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.652065 [info     ] No close match found for '2009-06-20t07:52:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.653232 [info     ] No close match found for '2009-06-20t08:56:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.654568 [info     ] No close match found for '2009-06-20t08:22:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.655762 [info     ] No close match found for '2009-06-24t17:17:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.658387 [info     ] No close match found for '2009-06-20t05:20:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.660215 [info     ] No close match found for '2009-06-20t11:27:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.664345 [info     ] No close match found for '2009-06-25t17:15:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.668252 [info     ] No close match found for '2009-06-20t03:03:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.671709 [info     ] No close match found for '2009-06-20t10:46:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.678110 [info     ] No close match found for '2009-06-23t20:23:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.685030 [info     ] No close match found for '2009-06-22t09:32:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.686868 [info     ] No close match found for '2009-06-22t09:22:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.688562 [info     ] No close match found for '2009-06-22t09:01:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.689848 [info     ] No close match found for '2009-06-22t08:55:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.693229 [info     ] No close match found for '2009-06-22t11:47:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.695587 [info     ] No close match found for '2009-06-20t10:47:00' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:18:38.698084 [info     ] No close match found for '2009-06-20t09:20:00' in category 'individuals' [OntologyAdapter]19:18:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:18:41 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:18:42 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T01:18:42.763654 [error    ] Embedding error with model openai/text-embedding-3-large: litellm.NotFoundError: OpenAIException - Error code: 403 - {'error': {'message': 'Project `proj_9jZSxRu3eKe0nPXxclmLpJT4` does not have access to model `text-embedding-3-large`', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}} [LiteLLMEmbeddingEngine]
# 2025-07-07T01:18:42.764924 [error    ] EmbeddingException: Failed to index data points using model openai/text-embedding-3-large (Status code: 422) [cognee.shared.logging_utils]
# 2025-07-07T01:18:42.766092 [warning  ] Failed to index data points for EntityType.name: EmbeddingException: Failed to index data points using model openai/text-embedding-3-large (Status code: 422) [index_data_points]
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# 19:18:43 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:18:44 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T01:18:44.648530 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:45 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:46 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:46 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:46 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:46 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:18:47 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# 2025-07-07T01:18:48.003995 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]19:18:49 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:18:50 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T01:18:51.093241 [error    ] Embedding error with model openai/text-embedding-3-large: litellm.NotFoundError: OpenAIException - Error code: 403 - {'error': {'message': 'Project `proj_9jZSxRu3eKe0nPXxclmLpJT4` does not have access to model `text-embedding-3-large`', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}} [LiteLLMEmbeddingEngine]
# 2025-07-07T01:18:51.094944 [error    ] EmbeddingException: Failed to index data points using model openai/text-embedding-3-large (Status code: 422) [cognee.shared.logging_utils]
# 2025-07-07T01:18:51.095808 [warning  ] Failed to index data points for Entity.name: EmbeddingException: Failed to index data points using model openai/text-embedding-3-large (Status code: 422) [index_data_points]
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# 19:18:51 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:18:51 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:18:53 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T01:18:53.287218 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
# 2025-07-07T01:18:53.716330 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
# 2025-07-07T01:18:54.127279 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
# 2025-07-07T01:18:54.700077 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]19:18:55 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:55 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:55 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:55 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:55 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:55 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:18:55 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:19:06 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:06 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:06 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:06 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:07 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:07 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:09 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:09 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:19:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:07 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:07 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# 2025-07-07T01:20:07.501490 [info     ] No close match found for 'vendor' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:20:07.502514 [info     ] No close match found for 'vts' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.503715 [info     ] No close match found for 'payment_type' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:20:07.504618 [info     ] No close match found for 'credit' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.505849 [info     ] No close match found for 'cash' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.506987 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:20:07.508903 [info     ] No close match found for '2009-06-04' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.510456 [info     ] No close match found for '2009-06-08' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.512069 [info     ] No close match found for '2009-06-02' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.514003 [info     ] No close match found for '2009-06-03' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.515327 [info     ] No close match found for '2009-06-05' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.516693 [info     ] No close match found for '2009-06-06' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.518333 [info     ] No close match found for 'trip' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:20:07.519420 [info     ] No close match found for 'trip 1' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.520715 [info     ] No close match found for 'trip 2' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.522000 [info     ] No close match found for 'trip 3' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.523245 [info     ] No close match found for 'trip 4' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.524854 [info     ] No close match found for 'trip 5' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.526271 [info     ] No close match found for 'trip 6' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.532020 [info     ] No close match found for 'trip 7' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.534145 [info     ] No close match found for 'trip 8' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.536158 [info     ] No close match found for 'trip 9' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.538040 [info     ] No close match found for 'trip 10' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.540102 [info     ] No close match found for 'trip 11' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.541626 [info     ] No close match found for 'trip 12' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.544159 [info     ] No close match found for 'trip 13' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.548396 [info     ] No close match found for 'trip 14' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.551754 [info     ] No close match found for 'trip 15' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.553681 [info     ] No close match found for 'trip 16' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.555461 [info     ] No close match found for 'trip 17' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.557144 [info     ] No close match found for 'trip 18' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.560212 [info     ] No close match found for 'trip 19' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.562948 [info     ] No close match found for 'trip 20' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.564631 [info     ] No close match found for 'trip 21' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.566861 [info     ] No close match found for 'trip 22' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.568422 [info     ] No close match found for 'trip 23' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.569948 [info     ] No close match found for 'trip 24' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.571480 [info     ] No close match found for 'trip 25' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.572523 [info     ] No close match found for 'trip 26' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.573707 [info     ] No close match found for 'trip 27' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.575874 [info     ] No close match found for 'trip 28' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.576767 [info     ] No close match found for 'trip 29' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.578889 [info     ] No close match found for 'trip 30' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.583989 [info     ] No close match found for 'cmt' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.585648 [info     ] No close match found for 'paymenttype' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:20:07.587544 [info     ] No close match found for 'june 7, 2009' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.590665 [info     ] No close match found for 'location' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:20:07.592145 [info     ] No close match found for '0.0, 0.0' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.593512 [info     ] No close match found for '2009-06-01' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.595601 [info     ] No close match found for '2009-06-09' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.597672 [info     ] No close match found for '2009-06-01' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.599641 [info     ] No close match found for '2009-06-02' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.600689 [info     ] No close match found for '2009-06-03' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.601961 [info     ] No close match found for '2009-06-04' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.603124 [info     ] No close match found for '2009-06-05' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.604682 [info     ] No close match found for '2009-06-06' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.605997 [info     ] No close match found for '2009-06-07' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.607306 [info     ] No close match found for '2009-06-08' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.608913 [info     ] No close match found for '2009-06-09' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.610974 [info     ] No close match found for 'passengercount' in category 'classes' [OntologyAdapter]
# 2025-07-07T01:20:07.612920 [info     ] No close match found for '1' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.615405 [info     ] No close match found for '2' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.617955 [info     ] No close match found for '3' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.619339 [info     ] No close match found for '4' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.620685 [info     ] No close match found for '5' in category 'individuals' [OntologyAdapter]
# 2025-07-07T01:20:07.622924 [info     ] No close match found for '6' in category 'individuals' [OntologyAdapter]19:20:08 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:20:09 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:20:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:20:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:20:12 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T01:20:13.019170 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]19:20:13 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:20:13 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:20:13 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:20:13 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:20:13 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:20:13 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:20:13 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:15 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:16 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:16 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:16 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:20:16 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# 2025-07-07T01:20:16.802064 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]19:20:18 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:20:19 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:20:19 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:20:20 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:20:20 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:20:21 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large
# 2025-07-07T01:20:22.432225 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
# 2025-07-07T01:20:22.909773 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
# 2025-07-07T01:20:23.317197 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
# 2025-07-07T01:20:23.830673 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
# 2025-07-07T01:20:24.240548 [info     ] Coroutine task completed: `check_permissions_on_dataset` [run_tasks_base]
# 2025-07-07T01:20:24.750898 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
# 2025-07-07T01:20:25.161415 [info     ] Pipeline run completed: `323d968a-862f-52a4-92d5-6b83cba96071` [run_tasks(tasks: [Task], data)]
# 2025-07-07T01:20:25.615409 [info     ] Graph visualization saved as graph_output/graph_visualization.html [cognee.shared.logging_utils]
# 2025-07-07T01:20:25.617359 [info     ] The HTML file has been stored at path: graph_output/graph_visualization.html [cognee.shared.logging_utils]

# %%
async def search_cognee(query, node_set, query_type=SearchType.GRAPH_COMPLETION):
    answer = await cognee.search(
        query_text=query,
        query_type=query_type,
        node_type=NodeSet,
        node_name=node_set,
        top_k=5 # limit search for retrieval
    )
    return answer

# %%
results = await search_cognee(
    "What's in this knowledge graph?",
    node_set=["first_10_days"]
)
# Out:
# 19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:57 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large19:43:58 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai19:44:01 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1819:44:02 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18

# %%
print(results[0])
# Out:
# The knowledge graph contains nodes representing specific dates and ride details from a taxi service, including information like pickup and drop-off times, coordinates, fare amounts, payment types, and passenger counts. Key relationships include connections between dates and various trips, summarized by passenger counts (1 to 6). The main date in focus is '2009-06-09', which has multiple related trip entries.

# %%
results = await search_cognee(
    "What are the most payment method used?",
    node_set=["first_10_days"]
)
# Out:
# 20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:10 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:11 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:11 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/text-embedding-3-large
# selected model name for cost calculation: openai/text-embedding-3-large20:17:12 - LiteLLM:INFO: utils.py:2929 -
# LiteLLM completion() model= gpt-4o-mini; provider = openai
#
# LiteLLM completion() model= gpt-4o-mini; provider = openai20:17:13 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-1820:17:13 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18
# selected model name for cost calculation: openai/gpt-4o-mini-2024-07-18

# %%
print(results[0])
# Out:
# The most used payment method mentioned in the context is cash, which is accepted and offered by the taxicab vendor company (vts).
